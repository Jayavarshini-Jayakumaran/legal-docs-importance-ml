# %% [markdown]
# # Data Preprocessing
# Project: Legal Document Importance Prediction
# Objective: Prepare clean, model-ready features from raw legal documents
#
# > **Note:** This notebook is for experimentation.
# > Production code lives in `src/data_preprocessing.py`.

# %% [markdown]
# ## Imports

# %%
import csv
import re
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Memory-Safe CSV Reader

# %% [markdown]
# pandas' C parser raises `out of memory` on large files on Windows.
# We use Python's built-in `csv` module instead, streaming row-by-row into
# per-column lists so peak RAM stays minimal.

# %%
def read_csv_safe(path):
    """Stream CSV into per-column lists — avoids pandas C parser OOM."""
    columns = None
    col_data = {}
    with open(path, newline="", encoding="utf-8", errors="replace") as f:
        reader = csv.reader(f)
        for i, row in enumerate(reader):
            if i == 0:
                columns = row
                col_data = {c: [] for c in columns}
            else:
                for c, val in zip(columns, row):
                    col_data[c].append(val)
    df = pd.DataFrame(col_data)
    for col in df.columns:
        try:
            df[col] = pd.to_numeric(df[col])
        except (ValueError, TypeError):
            pass
    return df

# %% [markdown]
# ## 2. Load Raw Datasets

# %%
train_df = read_csv_safe("../data/raw/train.csv")
test_df  = read_csv_safe("../data/raw/test.csv")

train_df.columns = train_df.columns.str.strip().str.replace(" ", "_")
test_df.columns  = test_df.columns.str.strip().str.replace(" ", "_")

print(f"Train: {train_df.shape} | Test: {test_df.shape}")

# %% [markdown]
# ## 3. Working Copies

# %%
train_clean = train_df.copy()
test_clean  = test_df.copy()

# %% [markdown]
# ## 4. Handle Missing Values

# %%
text_cols = ["Headline", "Reasoning", "Key_Insights", "Tags"]
list_cols = ["Lead_Types", "Power_Mentions", "Agencies"]

train_clean[text_cols] = train_clean[text_cols].fillna("")
test_clean[text_cols]  = test_clean[text_cols].fillna("")

train_clean[list_cols] = train_clean[list_cols].fillna("")
test_clean[list_cols]  = test_clean[list_cols].fillna("")

# %% [markdown]
# ## 5. Fix Encoding & Normalize Text

# %%
def fix_encoding(text):
    if not isinstance(text, str):
        return text
    return re.sub(r"â€'|â€“|â€”", "-", text)

for col in ["Headline", "Key_Insights", "Reasoning"]:
    train_clean[col] = train_clean[col].apply(fix_encoding).str.lower().str.strip()
    test_clean[col]  = test_clean[col].apply(fix_encoding).str.lower().str.strip()

# %% [markdown]
# ## 6. Parse List-like Columns

# %% [markdown]
# **Key fix:** list columns are stored as semicolon-separated strings (e.g. `'FBI; DOJ'`).
# We parse them into real Python lists *before* computing any counts,
# so `.apply(len)` returns list length, not string length.

# %%
def split_to_list(text):
    if not text or not isinstance(text, str):
        return []
    return [t.strip() for t in text.split(";") if t.strip()]

for col in list_cols:
    train_clean[col] = train_clean[col].apply(split_to_list)
    test_clean[col]  = test_clean[col].apply(split_to_list)

# Verify — should show a list, not a string length
train_clean["Lead_Types"].head(3)

# %% [markdown]
# ## 7. Base Features

# %%
for df in [train_clean, test_clean]:
    df["headline_len"]       = df["Headline"].str.len()
    df["insight_len"]        = df["Key_Insights"].str.len()
    df["num_lead_types"]     = df["Lead_Types"].apply(len)
    df["num_power_mentions"] = df["Power_Mentions"].apply(len)
    df["num_agencies"]       = df["Agencies"].apply(len)
    df["num_tags"]           = df["Tags"].apply(lambda x: len(x.split(";")) if x else 0)

# %% [markdown]
# ## 8. Drop Non-Predictive Columns

# %%
for df in [train_clean, test_clean]:
    if "Source_File" in df.columns:
        df.drop(columns=["Source_File"], inplace=True)

# %% [markdown]
# ## 9. Final Check & Save

# %%
train_clean.info()

# %%
train_clean.to_csv("../data/processed/train_clean.csv", index=False)
test_clean.to_csv("../data/processed/test_clean.csv", index=False)
print("Saved.")

# %% [markdown]
# ## Summary
# - CSV loaded with memory-safe column-streaming reader
# - Missing values filled appropriately per column type
# - Encoding artifacts fixed; text lowercased and stripped
# - List columns parsed into real Python lists before count features
# - Base count and length features added
# - Non-predictive columns dropped

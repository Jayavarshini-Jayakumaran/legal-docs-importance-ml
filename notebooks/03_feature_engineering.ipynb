# %% [markdown]
# # Feature Engineering
# Project: Legal Document Importance Prediction
# Objective: Create advanced, model-ready features from cleaned data
#
# > **Note:** This notebook is for experimentation.
# > Production code lives in `src/feature_engineering.py`.

# %% [markdown]
# ## Imports

# %%
import ast
import csv
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## 1. Load Clean Data

# %%
def read_csv_safe(path):
    columns = None
    col_data = {}
    with open(path, newline="", encoding="utf-8", errors="replace") as f:
        reader = csv.reader(f)
        for i, row in enumerate(reader):
            if i == 0:
                columns = row
                col_data = {c: [] for c in columns}
            else:
                for c, val in zip(columns, row):
                    col_data[c].append(val)
    df = pd.DataFrame(col_data)
    for col in df.columns:
        try:
            df[col] = pd.to_numeric(df[col])
        except (ValueError, TypeError):
            pass
    return df

train_df = read_csv_safe("../data/processed/train_clean.csv")
test_df  = read_csv_safe("../data/processed/test_clean.csv")

# %% [markdown]
# ## 2. Parse List Columns

# %% [markdown]
# List columns are saved as stringified lists by CSV round-trip. Parse them back before any `.apply(len)` call.

# %%
def parse_list_col(x):
    if isinstance(x, list): return x
    if not isinstance(x, str) or not x.strip(): return []
    s = x.strip()
    if s.startswith("[") and s.endswith("]"):
        try: return ast.literal_eval(s)
        except: pass
    return [t.strip() for t in s.split(";") if t.strip()]

list_cols = ["Lead_Types", "Power_Mentions", "Agencies"]
for col in list_cols:
    train_df[col] = train_df[col].apply(parse_list_col)
    test_df[col]  = test_df[col].apply(parse_list_col)

# Recompute counts on real lists
for df in [train_df, test_df]:
    df["num_lead_types"]     = df["Lead_Types"].apply(len)
    df["num_power_mentions"] = df["Power_Mentions"].apply(len)
    df["num_agencies"]       = df["Agencies"].apply(len)

# %% [markdown]
# ## 3. Base Text Length Features

# %%
for df in [train_df, test_df]:
    df["headline_len"] = df["Headline"].fillna("").str.len()
    df["insight_len"]  = df["Key_Insights"].fillna("").str.len()
    df["reason_len"]   = df["Reasoning"].fillna("").str.len()

# %% [markdown]
# ## 4. Density & Ratio Features

# %%
for df in [train_df, test_df]:
    n_pm = df["num_power_mentions"]
    n_ag = df["num_agencies"]
    n_lt = df["num_lead_types"]
    il   = df["insight_len"]
    rl   = df["reason_len"]
    hl   = df["headline_len"]

    df["agency_density"]        = n_ag / (il + 1)
    df["institutional_index"]   = n_ag + n_lt
    df["lead_complexity_ratio"] = n_lt / (n_pm + 1)
    df["insight_concentration"] = il   / (rl + 1)
    df["entity_insight_ratio"]  = n_pm / (il + 1)
    df["tag_lead_alignment"]    = df["num_tags"] / (n_lt + 1)
    df["actionability_proxy"]   = n_pm + n_ag + n_lt
    df["information_density"]   = (il + rl) / (hl + 1)
    df["power_density"]         = n_pm / np.log1p(hl + il)

# %% [markdown]
# ## 5. Importance Prior

# %% [markdown]
# Group mean of `Importance_Score` by `num_power_mentions` — computed on train only.
# Test set receives the global training mean to prevent leakage.

# %%
prior_map    = train_df.groupby("num_power_mentions")["Importance_Score"].mean()
global_prior = train_df["Importance_Score"].mean()

train_df["importance_prior"] = (
    train_df["num_power_mentions"].map(prior_map).fillna(global_prior)
)
test_df["importance_prior"] = global_prior

print(f"Global prior: {global_prior:.2f}")

# %% [markdown]
# ## 6. Investigative Intent Features

# %%
def compute_intent_score(row):
    score  = row["num_lead_types"]     * 2
    score += row["num_agencies"]       * 3
    score += row["num_power_mentions"]
    score += row["insight_len"]        / 150
    return score

def map_intent_category(score):
    if score <= 1:   return "contextual"
    elif score <= 3: return "informational"
    elif score <= 6: return "disclosure"
    elif score <= 9: return "analytical"
    else:            return "allegational"

intent_encoding = {"contextual": 0, "informational": 1,
                   "disclosure": 2, "analytical": 3, "allegational": 4}

for df in [train_df, test_df]:
    df["intent_score"] = df.apply(compute_intent_score, axis=1)
    df["intent_level"] = df["intent_score"].apply(map_intent_category).map(intent_encoding)

train_df[["intent_score", "intent_level"]].head()

# %% [markdown]
# ## 7. Semantic Alignment (TF-IDF Cosine)

# %% [markdown]
# **Why not SBERT?** The `paraphrase-MiniLM-L3-v2` model requires ~66MB RAM to load
# plus additional memory during encoding of 20k long legal documents — this caused
# Windows paging file errors. TF-IDF cosine similarity captures the same signal
# (vocabulary overlap between Headline and Key_Insights) with minimal RAM,
# processed in chunks of 1,000 rows.

# %%
def _jaccard_row(h, i):
    h_tok = set(h.lower().split())
    i_tok = set(i.lower().split())
    if not h_tok or not i_tok: return 0.0
    return len(h_tok & i_tok) / len(h_tok | i_tok)

def add_semantic_alignment(df, prefix):
    headlines = df["Headline"].fillna("").astype(str).tolist()
    insights  = df["Key_Insights"].fillna("").astype(str).tolist()
    try:
        tfidf = TfidfVectorizer(max_features=2000, sublinear_tf=True,
                                analyzer="word", ngram_range=(1, 1), dtype=np.float32)
        tfidf.fit(headlines)
        scores = []
        for s in range(0, len(df), 1000):
            hv = tfidf.transform(headlines[s:s+1000])
            iv = tfidf.transform(insights[s:s+1000])
            dot     = np.array(hv.multiply(iv).sum(axis=1)).flatten()
            h_norms = np.sqrt(np.array(hv.multiply(hv).sum(axis=1)).flatten())
            i_norms = np.sqrt(np.array(iv.multiply(iv).sum(axis=1)).flatten())
            scores.extend((dot / np.maximum(h_norms * i_norms, 1e-10)).tolist())
            del hv, iv
        df["semantic_alignment"] = scores
    except MemoryError:
        print("[fallback] Using Jaccard similarity")
        df["semantic_alignment"] = [_jaccard_row(h, i) for h, i in zip(headlines, insights)]
    print(f"  {prefix}: mean semantic_alignment = {df['semantic_alignment'].mean():.3f}")
    return df

train_df = add_semantic_alignment(train_df, "train")
test_df  = add_semantic_alignment(test_df,  "test")

# %% [markdown]
# ## 8. Temporal & Legal Signal Features

# %%
date_pattern = r"\b(19|20)\d{2}\b"
legal_terms  = ["foia", "indict", "prosecut", "sanction", "oversight", "plea", "probe"]

for df in [train_df, test_df]:
    reasoning = df["Reasoning"].fillna("").astype(str)
    df["temporal_density"]    = reasoning.str.count(date_pattern) / (df["reason_len"] + 1)
    df["legal_trigger_count"] = reasoning.apply(
        lambda t: sum(term in t for term in legal_terms)
    )

train_df[["temporal_density", "legal_trigger_count"]].describe()

# %% [markdown]
# ## 9. Quick Validation

# %%
feature_cols = ["num_lead_types", "num_power_mentions", "num_agencies",
                "insight_len", "intent_score", "intent_level",
                "semantic_alignment", "legal_trigger_count", "importance_prior"]
train_df[feature_cols].head()

# %% [markdown]
# ## 10. Save

# %%
train_df.to_csv("../data/processed/train_features.csv", index=False)
test_df.to_csv("../data/processed/test_features.csv",  index=False)
print(f"Train features: {train_df.shape}")
print(f"Test features:  {test_df.shape}")

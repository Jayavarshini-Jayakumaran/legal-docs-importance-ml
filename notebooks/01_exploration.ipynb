# %% [markdown]
# # Exploratory Data Analysis
# Project: Legal Document Importance Prediction
# Goal: Understand document metadata & text patterns influencing Importance Score
#
# > **Note:** This notebook is for experimentation.
# > Production code lives in the `src/` directory.

# %% [markdown]
# ## Imports & Visualization Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
sns.set_theme(style="whitegrid", font_scale=1.1)

# %% [markdown]
# ## 1. Load Dataset

# %%
import csv

def read_csv_safe(path):
    """Memory-safe CSV reader used throughout the project."""
    columns = None
    col_data = {}
    with open(path, newline="", encoding="utf-8", errors="replace") as f:
        reader = csv.reader(f)
        for i, row in enumerate(reader):
            if i == 0:
                columns = row
                col_data = {c: [] for c in columns}
            else:
                for c, val in zip(columns, row):
                    col_data[c].append(val)
    df = pd.DataFrame(col_data)
    for col in df.columns:
        try:
            df[col] = pd.to_numeric(df[col])
        except (ValueError, TypeError):
            pass
    return df

df = read_csv_safe("../data/raw/train.csv")
df.columns = df.columns.str.strip().str.replace(" ", "_")
df.head()

# %% [markdown]
# ### Observations
# - The dataset contains structured legal document metadata along with rich textual fields such as Headline, Key Insights, and Reasoning.
# - The target variable **Importance_Score** is present only in the training data, confirming this as a supervised regression problem.

# %% [markdown]
# ## 2. Dataset Structure & Overview

# %%
df.shape

# %%
df.info()

# %% [markdown]
# - The dataset contains **20,624 documents with 10 columns**.
# - Most columns are text-based (`object`), indicating a strong **NLP-driven modeling requirement**.
# - Numeric columns are limited to `id` and the target `Importance_Score`.

# %% [markdown]
# ## 3. Statistical Summary

# %%
df.describe(include='all').T

# %% [markdown]
# - The **Importance_Score** ranges from **0 to 92**, with a median of **12**, indicating most documents are low to moderately important.
# - Text fields such as Headline, Reasoning, and Key Insights have very high uniqueness.
# - Some categorical fields (Lead_Types, Power_Mentions) show repeated themes, suggesting strong feature signals.

# %% [markdown]
# ## 4. Missing Value Analysis

# %%
df.isnull().sum()

# %%
(df.isnull().sum() / len(df)) * 100

# %% [markdown]
# ## 5. Column Inspection

# %%
df.sample(5)

# %%
df.nunique().sort_values(ascending=False)

# %%
df["Headline"].sample(5).tolist()

# %%
df["Key_Insights"].sample(5).tolist()

# %%
df["Lead_Types"].dropna().sample(5).tolist()

# %% [markdown]
# ## 6. Distribution of Numerical Features

# %%
df["headline_len"] = df["Headline"].fillna("").str.len()
df["insight_len"]  = df["Key_Insights"].fillna("").str.len()

# %%
num_cols = ["Importance_Score", "headline_len", "insight_len"]
df[num_cols].hist(bins=30, figsize=(12, 6))
plt.suptitle("Distribution of Numerical Features")
plt.show()

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(data=df[num_cols])
plt.title("Boxplot of Numerical Features")
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.heatmap(df[num_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - Importance Score shows **strong positive correlation** with `insight_len` (≈0.74) and `headline_len` (≈0.63).
# - Longer, detailed documents tend to be more investigatively valuable.

# %% [markdown]
# ## 7. Target Variable Analysis

# %%
sns.histplot(df["Importance_Score"], bins=30, kde=True)
plt.title("Distribution of Importance Score")
plt.show()
df["Importance_Score"].describe()

# %% [markdown]
# - Importance Score is **right-skewed** and heavily concentrated at lower values.
# - High scores are rare — only a few documents are critical, matching real-world investigative settings.

# %% [markdown]
# ## 8. Bivariate Analysis

# %%
sns.scatterplot(x="headline_len", y="Importance_Score", data=df)
plt.title("Headline Length vs Importance Score")
plt.show()

# %%
sns.scatterplot(x="insight_len", y="Importance_Score", data=df)
plt.title("Key Insights Length vs Importance Score")
plt.show()

# %%
df.groupby("Lead_Types")["Importance_Score"].mean().sort_values(ascending=False).head(10)

# %% [markdown]
# - Documents involving **sexual misconduct, human trafficking, obstruction of justice** consistently score highest.
# - **Content type and institutional involvement** are strong relevance signals.

# %% [markdown]
# ## 9. Summary

# %% [markdown]
# Key findings:
# - Importance Score is **highly right-skewed**; most documents are low value.
# - **Textual depth** (especially Key Insights length) is the strongest numeric predictor.
# - **Contextual metadata** — lead types, agency involvement, named entities — amplifies textual importance.
# - Outliers in Importance Score are **genuinely critical documents** and must be preserved.
#
# A **hybrid approach combining engineered features with gradient boosting** is best suited for this task.
